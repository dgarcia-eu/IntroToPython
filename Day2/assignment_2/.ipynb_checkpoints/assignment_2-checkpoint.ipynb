# %% [markdown]
# # Assignment 2: Lists, Tuples, Sets, Comprehensions, and if-statements
#
# Winter Semester 2025/26
#
# Total Score: 20 points
#
# Submission Deadline: Tuesday, October 14, 2025, 23:59

# %% [markdown]
# ## Task 1 (Total: 5 points)

# %% [markdown]
# 1. Make a list of names that includes at least four people.  (0 points)
# 2. Write an if test that prints a message about the room being crowded if there are more than three people in your list. (1 point)
# 3. Modify your list so that there are only two people in it. Use one of the methods for removing people from the list, don't just redefine the list. (1 point)
# 4. Run your if test about the length of point 2 again. There should be no output this time because there are less than three people in the list. (1 point)
# 5. Add an `else` statement to your if test of the point above. If the `else` statement is run, have it print a message that the room is not very crowded. (1 point)
# 6. Modify your if test so that:
#       - If there are more than 5 people, a message is printed about the room being very crowded.
#       - If there are 3-5 people, a message is printed about the room being crowded.
#       - If there are 1 or 2 people, a message is printed about the room not being crowded.
#       - If there are no people in the room, a message is printed abou the room being empty. (1 point)

# %%
# Your code here

# %% [markdown]
# ## Task 2 (Total: 9 points)
#
# The code below reads a pickle file containing date information about when tweets were published. The data is stored in a variable named `date`. Before running the code, you need to save the file "date_example.pickle" in your working directory.

# %%
import pickle

with open('date_example.pickle', 'rb') as handle:
    date = pickle.load(handle)

# %%
print(date)
# Out:
# ['Sun Feb 09 23:51:32 +0000 2020', 'Sun Feb 09 23:51:11 +0000 2020', 'Sun Feb 09 23:40:32 +0000 2020', 'Sun Feb 09 23:31:39 +0000 2020', 'Sun Feb 09 23:05:59 +0000 2020', 'Sun Feb 09 23:04:16 +0000 2020', 'Sun Feb 09 23:03:57 +0000 2020', 'Sun Feb 09 23:02:16 +0000 2020', 'Sun Feb 09 22:42:46 +0000 2020', 'Sun Feb 09 22:31:37 +0000 2020', 'Sun Feb 09 22:19:50 +0000 2020', 'Sun Feb 09 22:18:40 +0000 2020', 'Sun Feb 09 22:18:03 +0000 2020', 'Sun Feb 09 22:16:05 +0000 2020', 'Sun Feb 09 22:01:41 +0000 2020', 'Sun Feb 09 21:34:59 +0000 2020', 'Sun Feb 09 21:30:49 +0000 2020', 'Sun Feb 09 21:18:18 +0000 2020', 'Sun Feb 09 21:17:04 +0000 2020', 'Sun Feb 09 21:06:55 +0000 2020', 'Sun Feb 09 21:04:34 +0000 2020', 'Sun Feb 09 20:50:05 +0000 2020', 'Sun Feb 09 20:45:17 +0000 2020', 'Sun Feb 09 20:30:06 +0000 2020', 'Sun Feb 09 20:21:22 +0000 2020', 'Sun Feb 09 20:13:10 +0000 2020', 'Sun Feb 09 20:08:29 +0000 2020', 'Sun Feb 09 20:05:17 +0000 2020', 'Sun Feb 09 20:04:27 +0000 2020', 'Sun Feb 09 19:59:00 +0000 2020', 'Sun Feb 09 19:58:21 +0000 2020', 'Sun Feb 09 19:58:05 +0000 2020', 'Sun Feb 09 19:56:03 +0000 2020', 'Sun Feb 09 19:54:24 +0000 2020', 'Sun Feb 09 19:53:57 +0000 2020', 'Sun Feb 09 19:53:06 +0000 2020
15:20:13 +0000 2020', 'Sun Feb 09 15:11:00 +0000 2020', 'Sun Feb 09 15:06:43 +0000 2020', 'Sun Feb 09 15:02:02 +0000 2020', 'Sun Feb 09 15:01:33 +0000 2020', 'Sun Feb 09 14:58:38 +0000 2020', 'Sun Feb 09 14:58:32 +0000 2020', 'Sun Feb 09 14:57:37 +0000 2020', 'Sun Feb 09 14:54:46 +0000 2020', 'Sun Feb 09 14:54:09 +0000 2020', 'Sun Feb 09 14:50:09 +0000 2020', 'Sun Feb 09 14:48:52 +0000 2020', 'Sun Feb 09 14:48:00 +0000 2020', 'Sun Feb 09 14:44:08 +0000 2020', 'Sun Feb 09 14:41:06 +0000 2020', 'Sun Feb 09 14:39:11 +0000 2020', 'Sun Feb 09 14:31:58 +0000 2020', 'Sun Feb 09 14:30:37 +0000 2020', 'Sun Feb 09 14:28:18 +0000 2020', 'Sun Feb 09 14:16:26  ...

# %% [markdown]
# 1. Using `date`, create a new list containing only the months, day, and year for each date, in the following format. Use slicing and exactly one list comprehension such that the result looks like this: (3 points)
#
# ```python
#     ['Feb 09 2020', 'Feb 09 2020', 'Feb 09 2020',...,'Feb 03 2020', 'Feb 03 2020']

# %%
# Your code here

# %% [markdown]
# 2. Create the date list from Task 1 to the format 'YYYY-MM-DD' using the datetime library. (3 points)
#
# ```Python
#     ['2020-02-09', '2020-02-09',..., '2020-02-03', '2020-02-03']

# %%
from datetime import datetime
example = datetime.strptime('Feb 07 2020', '%b %d %Y')
print(example.strftime("%Y-%m-%d"))
# Out:
# 2020-02-07

# %%
# Your code here

# %% [markdown]
# 3. Use the list from Task 2 to create a list of tuples where each tuple contains a unique date and the count of its occurrences. Use exactly one list comprehension. The order of the output is not important but it should look like this: (3 points)
#
#
# ```Python
# [('2020-02-05', 1701),
#  ('2020-02-06', 620),
#  ('2020-02-08', 410),
#  ('2020-02-03', 962),
#  ('2020-02-09', 336),
#  ('2020-02-04', 937),
#  ('2020-02-07', 735)]

# %%
# Your code here

# %% [markdown]
# ## Task 3 (Total: 6 points)
# You have retweet data for five users, labeled **a, b, c, d, and e**. Each user list contains usernames of people who retweeted them. Your task is to find user pairs who have mutually retweeted each other.

# %%
user_a = ['b','c','e','h','r','b','b','c','h'] # User A is retweeted by user B, C, E, H...
user_b = ['a','c','a','h','z'] # User B is retweeted by user A, C, A,...
user_c = ['a','d','d']
user_d = ['a','b','e','a']
user_e = ['d','c','b','b']

# %% [markdown]
# 1. Create a list named **retweet_pairs** containing tuples with user retweet information. Each tuple should represent a retweet event. For example, (user1, user2) indicates the event when 'user1' was retweeted by 'user2'. This list should include all retweet events among the users. The list should look like the following but the order is not important: (3 points)
# ```python
#     [('a','b'), ('a', 'c'), ('a', 'e'),..., ('e', 'c'), ('e', 'b'), ('e', 'b')]

# %%
# Your code here

# %% [markdown]
# 2. Use **retweet_pairs** to find pairs of users who have mutually retweeted each other. Store those users in a set named **mutual_pairs** and print it. (3 points)

# %%
# Your code here
