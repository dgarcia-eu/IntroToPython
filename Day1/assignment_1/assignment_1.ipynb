# %% [markdown]
# ### Assignment 1: Variables, Strings, Numbers, Lists, and Loops
#
# Winter Semester 2025/26
#
# Total Score: 20 - 10 points needed to pass
#
# Submission Deadline: Monday, October 13, 2025, 23:59

# %% [markdown]
# ---
# **What this assignment builds on**
#
# Everything you need is in the notebooks below. If a task has you stuck, go back to the section named here before anything else — that is where the answer is worked through.
#
# | notebook | sections |
# |---|---|
# | `Day1/11_var_string_num.ipynb` | Strings — changing case, concatenation, whitespace and `\n`, `.split()`, `.format()` · Numbers · Built-in functions (`len()`) |
# | `Day1/12_lists_tuples-1.ipynb` | Introducing lists · Accessing items · Lists and looping · Appending and `extend()` · Finding an element in a list |
#
# Anything marked 🔍 in a task is deliberately *not* in this list: those ask you to look something up, and finding it is the point.
#
# ---

# %% [markdown]
# ---

# %% [markdown]
# The code below reads a text file containing an excerpt from the novel "The Old Man and the Sea". The text is stored in a variable named text. Before running the code, you need to save the file 'theoldmanandthesea.txt' in your working directory.
#
#
# You can check your current working directory using the following code.
#
# > ℹ️ **You do not need to understand the code in the next cell yet.** Reading files is covered on Day 4. For now, just run it — it puts the data into a variable for you.

# %%
with open('theoldmanandthesea.txt', 'r') as f:
    text = f.read()

# %% [markdown]
# ## Tasks
#
# 1. Print the text (1 point).

# %%
# Your code

# %% [markdown]
# 2. Convert all uppercase characters to lowercase in the text. From now on keep on working with the text converted to lowercase (1 point).

# %%
# Your code

# %% [markdown]
# 3. Split the text into a list of words named **text_split**, where each word is an item in the list (1 point).

# %%
# Your code

# %% [markdown]
# 4. Count and print the number of words in the list (1 point).

# %%
# Your code

# %% [markdown]
# 5. Create a variable called **next_text** that contains the following (1 point):
#
#     "Everything about him was old except his eyes and they were the same color as the sea and were cheerful and undefeated."

# %%
# Your code

# %% [markdown]
# 6. Modify **next_text** so it contains line breaks such that each word is in a new line (2 points).
#
#     Expected output of **print(next_text)** after modification:
#
#     Everything
#     about
#     him
#     was
#     old
#     except
#     ...
#
#    You should not use a loop for printing here, you have to modify **next_text**.

# %%
# Your code

# %% [markdown]
# 7. Update **text_split** by adding the words from **next_text**, so it becomes a single list (2 points).
#
#     Expected outcome of **print(text_split)** after updating it:
#
#     ['he', 'was', 'an', 'old', 'man',..., 'cheerful', 'and', 'undefeated.']

# %%
# Your code

# %% [markdown]
# 8. Using a loop, calculate the total number of characters in all the words of **text_split** (4 points).
#
#     Build this up in three steps. You can write it all in the cell below.
#
#     1. Create a variable `total` and set it to 0 before the loop starts. Then write a loop over **text_split** that adds the length of each word to `total`. (2 points)
#     2. Inside the same loop, print one line per word showing the word, its length, and the running total so far. (1 point)
#     3. After the loop has finished, print the final total on one line. (1 point)
#
#     Expected output:
#
#     word: he; length: 2; cumulative count: 2
#     word: was; length: 3; cumulative count: 5
#     ...
#     word: undefeated.; length: 11; cumulative count: 1022
#
#     total count : 1022

# %%
# Your code

# %% [markdown]
# 9. Create a list named **len_of_words** containing the length of each word in text_split (4 points).
#
#     [2, 3, 2, 3, 3, 3, ...]

# %%
# Your code

# %% [markdown]
# 10. Find and print the length of the longest word in the text (1 point).
#
#     *Hint: there is a built-in function that gives you the largest value in a list — you do not need a loop for this one.*

# %%
# Your code

# %% [markdown]
# 11. Identify and print the longest word using the index from **len_of_words** (2 points).

# %%
# Your code
