# %% [markdown]
# <font size="+3">Day 0: does everything work?</font>
#
# **Do this before Monday.** It takes ten minutes and it is not graded and it will save you headaches during the block course.
#
# It does two things:
#
# 1. **Checks your installation** for you to find out now rather than at 09:15 on Monday so you get lost or make the class wait.
# 2. **Shows you where you are starting from.** The course is built for people with no programming experience at all. If the last section makes no sense, it is totally OK and this course is for you. If all of it is easy, say hello on Monday and we will point you at the extra exercises.

# %% [markdown]
# ---
# ## Part 1 — the installation
#
# Run the next three cells. You do not need to understand them yet.
#
# ---

# %%
import sys
print('Python', sys.version.split()[0])
if sys.version_info < (3, 10):
    print('  -> This is older than we expect. Reinstall from the setup instructions.')
else:
    print('  -> Good.')

# %%
import pandas, matplotlib, numpy
print('pandas    ', pandas.__version__)
print('matplotlib', matplotlib.__version__)
print('numpy     ', numpy.__version__)
print('  -> Good, the three libraries we need are installed.')

# %%
import matplotlib.pyplot as plt
plt.plot([1, 4, 9, 16])
plt.title('If you can see this line, plotting works')
plt.show()

# %% [markdown]
# **Did all three run without a red error box, and did you get a plot?**
#
# * Yes — you are set up. Go to Part 2.
# * No — do not worry, and do not spend your evening on it. If you want to keep going in the meantime you can use the Binder link to work with an online environment: [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/dgarcia-eu/IntroToPython/refresh-2026). Treat it as a stopgap: it saves nothing, so download anything you write before closing the tab.

# %% [markdown]
# ---
# ## Part 2 — using the notebook
#
# Three things you will do a hundred times this week.
#
# ---

# %% [markdown]
# **Run a cell.** Click the cell below and press **Shift + Enter**.

# %%
print('Hello Python world!')

# %% [markdown]
# **Edit and re-run.** Change the name below to yours, then Shift + Enter again.

# %%
name = 'your name here'
print('Good luck this week,', name)

# %% [markdown]
# **Meet an error.** The cell below is broken on purpose. Run it, and read the message — the last line names the error and the arrow points at the cause. Reading errors is a skill, and we will practise it all week.
#
# Then fix it and run it again.

# %%
print('Hello world)

# %% [markdown]
# **Restart and run everything.** From the menu: *Kernel → Restart Kernel and Run All Cells*. This is how you check that your notebook works from a clean start, and it is the fix for most "but it worked a minute ago" problems.
#
# Note that the broken cell above will stop the run — that is expected until you have fixed it.

# %% [markdown]
# ---
# ## Part 3 — where are you starting from?
#
# Not a test. Nothing is recorded. Just read each block and ask yourself: *could I have written that?*
#
# ---

# %% [markdown]
# **Level 1.** Storing something and printing it.

# %%
message = 'Python is a language'
print(message)
print(message.upper())

# %% [markdown]
# **Level 2.** Doing something to every item of a list.

# %%
words = ['the', 'old', 'man', 'and', 'the', 'sea']
for word in words:
    print(word, len(word))

# %% [markdown]
# **Level 3.** Building up an answer while looping.

# %%
words = ['the', 'old', 'man', 'and', 'the', 'sea']
total = 0
for word in words:
    total = total + len(word)
print('total characters:', total)

# %% [markdown]
# **Level 4.** The same thing, written the short way.

# %%
words = ['the', 'old', 'man', 'and', 'the', 'sea']
print(sum([len(w) for w in words]))

# %% [markdown]
# ### How did that go?
#
# | If... | then |
# |---|---|
# | none of it was familiar | **Perfect.** This is exactly the starting point the course assumes. Do nothing else. |
# | levels 1–2 made sense, 3–4 did not | **Also perfect.** Level 3 is Day 1 and level 4 is Day 2. |
# | all four were easy | You will be ahead. Every assignment has ungraded **extra exercises**. Do those instead of waiting so you can start preparing for ICSS. Say hello on Monday so I know who starts ahead. |
#
# Nobody is expected to already know this. The one thing that genuinely helps before Monday is having Part 1 working.
#
# See you on Monday!
